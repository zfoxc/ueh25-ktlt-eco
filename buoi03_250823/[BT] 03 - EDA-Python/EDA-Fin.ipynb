# %% [markdown]
# # Buổi 04: Đầu tư định lượng dùng Pandas

# %%
# !pip install pandas_datareader
# !pip install yfinance
# !pip install mplfinance

# %%
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import mplfinance as mpf 
import seaborn as sns
import datetime as dt
# %matplotlib inline

# sửa lỗi tải dữ liệu của pandas_datareader
from IPython.display import display
import yfinance as yf
yf.pdr_override()

# %%
end = dt.datetime.now()
start = dt.datetime(2016, 1, 1)
print(f'{start} -> {end}')

df = web.DataReader('AAPL', start, end)
# Out:
# 2016-01-01 00:00:00 -> 2024-04-20 10:20:27.317186
# [*********************100%%**********************]  1 of 1 completed

# %%
display(df.head())
display(df.tail())
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2016-01-04  25.652500  26.342501  25.500000  26.337500  23.946918  270597600
# 2016-01-05  26.437500  26.462500  25.602501  25.677500  23.346825  223164000
# 2016-01-06  25.139999  25.592501  24.967501  25.174999  22.889933  273829600
# 2016-01-07  24.670000  25.032499  24.107500  24.112499  21.923874  324377600
# 2016-01-08  24.637501  24.777500  24.190001  24.240000  22.039803  283192000
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2024-04-15  175.360001  176.630005  ...  172.690002  73531800
# 2024-04-16  171.750000  173.759995  ...  169.380005  73711200
# 2024-04-17  169.610001  170.649994  ...  168.000000  50901200
# 2024-04-18  168.029999  168.639999  ...  167.039993  43122900
# 2024-04-19  166.210007  166.399994  ...  165.000000  67772100
#
# [5 rows x 6 columns]

# %%
df.loc['2024-04-19']
# Out:
# Open         1.662100e+02
# High         1.664000e+02
# Low          1.640800e+02
# Close        1.650000e+02
# Adj Close    1.650000e+02
# Volume       6.777210e+07
# Name: 2024-04-19 00:00:00, dtype: float64

# %%
df.to_csv('AAPL.csv')
df1 = pd.read_csv('AAPL.csv', index_col='Date')

# %%
display(df1)
# Out:
#                   Open        High  ...   Adj Close     Volume
# Date                                ...
# 2016-01-04   25.652500   26.342501  ...   23.946918  270597600
# 2016-01-05   26.437500   26.462500  ...   23.346825  223164000
# 2016-01-06   25.139999   25.592501  ...   22.889933  273829600
# 2016-01-07   24.670000   25.032499  ...   21.923874  324377600
# 2016-01-08   24.637501   24.777500  ...   22.039803  283192000
# ...                ...         ...  ...         ...        ...
# 2024-04-15  175.360001  176.630005  ...  172.690002   73531800
# 2024-04-16  171.750000  173.759995  ...  169.380005   73711200
# 2024-04-17  169.610001  170.649994  ...  168.000000   50901200
# 2024-04-18  168.029999  168.639999  ...  167.039993   43122900
# 2024-04-19  166.210007  166.399994  ...  165.000000   67772100
#
# [2088 rows x 6 columns]

# %%
df['Adj Close'].plot(legend=True, figsize=(12,8), title='AAPL', label = 'Adj Close')
# Out:
# <Axes: title={'center': 'AAPL'}, xlabel='Date'>

# %%
plt.figure(figsize=(12, 9))

top = plt.subplot2grid((12, 9), (0, 0), rowspan=10, colspan=9)
bottom = plt.subplot2grid((12, 9), (10, 0), rowspan=2, colspan=9)

top.plot(df.index, df['Adj Close'], color='blue')
bottom.bar(df.index, df['Volume'])

top.axes.get_xaxis().set_visible(False)
top.set_title('AAPL')
top.set_ylabel('Adj Close')
bottom.set_ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
df.index
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2024-04-08', '2024-04-09', '2024-04-10', '2024-04-11',
#                '2024-04-12', '2024-04-15', '2024-04-16', '2024-04-17',
#                '2024-04-18', '2024-04-19'],
#               dtype='datetime64[ns]', name='Date', length=2088, freq=None)

# %% [markdown]
# # End
